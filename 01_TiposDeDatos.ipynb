# %% [markdown]
# ## Entrada de datos desde teclado

# %%
# Tipos de varibles 
a=2
b=30
c="Hola"
d=True
e='Hello'
f=83.5

# %%
print(type (a))
print(type (b))
print(type (c))
print(type (d))
print(type (e))
print(type (f))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>
# <class 'float'>

# %%
# Lectura de una cadena 
name=input("Dame el name: ")
print(f"Hola: {name}")
# Out:
# Hola: Yuki

# %%
edad=int(input("Dime tueda"))
print(f"Hola {name} tienes {edad}")
# Out:
# Hola Yuki tienes 22

# %%
datoF=float(input("Valor de tipo float"))
print(datoF)
type(datoF)
# Out:
# 5.5
# float

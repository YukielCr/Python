# %% [markdown]
# ## El pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("csv/equipos.csv")
df.head(1)
# Out:
#     no equipo  sede                estadio mascota     colores
# 0  100   UNAM  CDMX  Estadio Universitario    Puma  azul y oro

# %%
df2=pd.read_csv("csv/equipos.csv",index_col="no")
df2.head(1)
# Out:
#     equipo  sede                estadio mascota     colores
# no
# 100   UNAM  CDMX  Estadio Universitario    Puma  azul y oro

# %%
# leer los primeros reguistros 
df2.head(1)
# Out:
#     equipo  sede                estadio mascota     colores
# no
# 100   UNAM  CDMX  Estadio Universitario    Puma  azul y oro

# %%
# leer los ultimos reguistros 
df2.tail(1)
# Out:
#      equipo    sede               estadio  mascota colores
# no
# 160  Toluca  Toluca  Estadio Nemezio Diaz  Diables    Rojo

# %%
df3 = pd.read_csv("csv/dataset30min.csv") 
df3.head(1)
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
#
#    retweets  mentions  country           user  followers  followees
# 0       NaN      10.0  ECUADOR  leonardokuffo      389.0        258

# %%
df3.tail(1)
# Out:
#         id                                          full_text  favorites  \
# 26  183747  I do not know if i like programming or other t...      318.0
#
#     retweets  mentions country             user  followers  followees
# 26      58.0      20.0  BRASIL  isabelladasilva      928.0       9918

# %%
df4 = pd.read_csv("csv/dataset30min.csv",index_col="id") 
df4.head(1)
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258

# %%
# obtener estadisticas descriptivas, de los datos del dataframe:
#cuenta, media, desviación estandar, valor minimo y maximo, cuartiles(Freund y Perles)
df4.describe()
# Out:
#         favorites    retweets   mentions   followers    followees
# count   26.000000   26.000000  26.000000   26.000000    27.000000
# mean   280.538462   80.000000  15.423077  352.807692  1190.185185
# std    153.377242   40.303846   9.596554  375.319493  1965.735995
# min     23.000000   21.000000   1.000000   12.000000   129.000000
# 25%    139.250000   45.500000   8.250000   21.000000   258.000000
# 50%    305.500000   79.000000  16.000000  332.000000   351.000000
# 75%    422.500000  110.750000  23.500000  389.000000  1822.000000
# max    500.000000  146.000000  29.000000  982.000000  9918.000000

# %%
df3.describe()
# Out:
#                   id   favorites    retweets   mentions   followers  \
# count      27.000000   26.000000   26.000000  26.000000   26.000000
# mean   183734.000000  280.538462   80.000000  15.423077  352.807692
# std         7.937254  153.377242   40.303846   9.596554  375.319493
# min    183721.000000   23.000000   21.000000   1.000000   12.000000
# 25%    183727.500000  139.250000   45.500000   8.250000   21.000000
# 50%    183734.000000  305.500000   79.000000  16.000000  332.000000
# 75%    183740.500000  422.500000  110.750000  23.500000  389.000000
# max    183747.000000  500.000000  146.000000  29.000000  982.000000
#
#          followees
# count    27.000000
# mean   1190.185185
# std    1965.735995
# min     129.000000
# 25%     258.000000
# 50%     351.000000
# 75%    1822.000000
# max    9918.000000

# %%
df4.head(1)
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258

# %% [markdown]
# ## Limpieza de Datos

# %%
df4
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
# vamos a filtrar o quitar las filas con valores vacios o incompletos 
df4limpio = df4.dropna()
df4limpio
# Out:
#                                                 full_text  favorites  \
# id
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183733                           Programming is the best!      467.0
# 183734                             I cannot believe this!       50.0
# 183735                             Buy this product NOW!!      418.0
# ...

# %%
df4limpio.describe()
# Out:
#         favorites    retweets   mentions   followers    followees
# count   23.000000   23.000000  23.000000   23.000000    23.000000
# mean   275.695652   81.130435  15.347826  338.695652  1285.869565
# std    143.138025   38.275680   9.735636  369.501806  2101.492831
# min     43.000000   24.000000   1.000000   12.000000   129.000000
# 25%    145.500000   51.000000   7.000000   21.000000   258.000000
# 50%    296.000000   82.000000  17.000000  332.000000   378.000000
# 75%    389.500000  110.500000  23.000000  389.000000  1822.000000
# max    492.000000  146.000000  29.000000  982.000000  9918.000000

# %%
# Llenar los valores vasios con un valor indicado en este caso 0
df4_0=df4.fillna(11111111)
df4_0
# Out:
#                                                 full_text   favorites  \
# id
# 183721  Flying home to run down from the power to comi...        23.0
# 183722                Today we commemorate and MNML Case.       500.0
# 183723       Today we have reached US$6.55 Billion TT$44…       190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...       131.0
# 183725                                    Welcome back! 🙌       113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!       492.0
# 183727                                 80's & friends! ✈️       158.0
# 183728  Thank you guess how did I feel somewhat offend...  11111111.0
# 183729        OnePlus 8 international giveaway classifies       198.0
# 183730                Here it is.. Retweet this desperate       272.0
# 183731  Great to advertise during the year I tweeted a...        43.0
# 183732  Its been in love with the game with the origin...       349.0
# ...

# %%
df4_0.describe()
# Out:
#           favorites      retweets      mentions     followers    followees
# count  2.700000e+01  2.700000e+01  2.700000e+01  2.700000e+01    27.000000
# mean   4.117928e+05  4.115997e+05  4.115375e+05  4.118624e+05  1190.185185
# std    2.138280e+06  2.138319e+06  2.138331e+06  2.138266e+06  1965.735995
# min    2.300000e+01  2.100000e+01  1.000000e+00  1.200000e+01   129.000000
# 25%    1.455000e+02  4.700000e+01  8.500000e+00  2.100000e+01   258.000000
# 50%    3.150000e+02  8.200000e+01  1.700000e+01  3.320000e+02   351.000000
# 75%    4.270000e+02  1.130000e+02  2.500000e+01  6.585000e+02  1822.000000
# max    1.111111e+07  1.111111e+07  1.111111e+07  1.111111e+07  9918.000000

# %%
df4
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
# vamos a rellenar la columna retweets, y la columna mentions, que estén vacias, 
#con un valor de 1 para retweets y -1 para mentions


df4=df4.fillna({"retweets":1000,"mentions":-1000})
df4
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

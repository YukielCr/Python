# %% [markdown]
# ## Leectura de un nuevo archivo

# %%
import pandas as pd

# %%
df=pd.read_csv("Python Tiburcio/datosx.csv")

# %%
# Informasion del data Frame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nc           13 non-null     int64
#  1   nombre       13 non-null     object
#  2   carrera      13 non-null     object
#  3   cooperacion  12 non-null     float64
#  4   sexo         13 non-null     object
#  5   procedencia  13 non-null     object
#  6   Edad         12 non-null     float64
#  7   Peso         13 non-null     float64
#  8   Estatura     12 non-null     float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.0+ KB

# %%
# Tamaño del Data Frame
# Filas x Columnas 
df.shape
# Out:
# (13, 9)

# %%
df.size
# Out:
# 117

# %%
# Lista de los nombres de las columnas 
df.columns
# Out:
# Index(['nc', 'nombre', 'carrera', 'cooperacion', 'sexo', 'procedencia', 'Edad',
#        'Peso', 'Estatura'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
df2=pd.read_csv("Python Tiburcio/datosx.csv",index_col="nc")

# %%
df2.index
# Out:
# Index([18090907, 17091058, 18091045, 18091054, 18091065, 19090356, 19090333,
#        18090233, 18091049, 18090961, 21091037, 22090333, 22090555],
#       dtype='int64', name='nc')

# %%
df2.dtypes
# Out:
# nombre          object
# carrera         object
# cooperacion    float64
# sexo            object
# procedencia     object
# Edad           float64
# Peso           float64
# Estatura       float64
# dtype: object

# %%
df.head(3)
# Out:
#          nc                            nombre carrera  cooperacion       sexo  \
# 0  18090907      Angel Axel Cuaxilo Rodirguez     ISC        100.0  Masculino
# 1  17091058  Everest Daniel Gutierrez Andrade     ISC        100.0  Masculino
# 2  18091045    Aurora de Jesus Linares Jacobo     ISC        100.0   Femenino
#
#   procedencia  Edad  Peso  Estatura
# 0    Amacuzac  21.0  80.0      1.75
# 1    Ocuituco  21.0  78.0      1.70
# 2     Temixco  22.0  65.0      1.65

# %% [markdown]
# ## Cambiar el nombre de columnas en el Data Frame

# %%
df
# Out:
#           nc                            nombre carrera  cooperacion  \
# 0   18090907      Angel Axel Cuaxilo Rodirguez     ISC        100.0
# 1   17091058  Everest Daniel Gutierrez Andrade     ISC        100.0
# 2   18091045    Aurora de Jesus Linares Jacobo     ISC        100.0
# 3   18091054            Mario Martinez Arteaga     ISC          NaN
# 4   18091065               Yeel Montes Camacho     ISC         50.0
# 5   19090356            Georgina Itzel Alvarez     ISC        150.0
# 6   19090333                    Britney Spears     ADM         80.0
# 7   18090233            Adrian Flores Herreram     ISC        100.0
# 8   18091049              Miriam Luna Aparicio     ISC        100.0
# 9   18090961    Salvador Jesus Barbina Cabrera     ISC        100.0
# 10  21091037                     Hernán Cortés    QUIM        100.0
# 11  22090333                     Juana de Arco     ADM        150.0
# 12  22090555                       Bruce Wayne    QUIM        150.0
#
# ...

# %%
dfnuevo=df.rename(columns={"nc":"Numero de comtrol","procedencia":"Origen"},index={0:100,1:200})
dfnuevo.head(4)
# Out:
#      Numero de comtrol                            nombre carrera  cooperacion  \
# 100           18090907      Angel Axel Cuaxilo Rodirguez     ISC        100.0
# 200           17091058  Everest Daniel Gutierrez Andrade     ISC        100.0
# 2             18091045    Aurora de Jesus Linares Jacobo     ISC        100.0
# 3             18091054            Mario Martinez Arteaga     ISC          NaN
#
#           sexo    Origen  Edad  Peso  Estatura
# 100  Masculino  Amacuzac  21.0  80.0      1.75
# 200  Masculino  Ocuituco  21.0  78.0      1.70
# 2     Femenino   Temixco  22.0  65.0      1.65
# 3    Masculino  Amacuzac  21.0  78.0      1.65

# %%
# Renombrar a uno en espesifico por su Id
dfnuevo.rename(index={2:400})
# Out:
#      Numero de comtrol                            nombre carrera  cooperacion  \
# 100           18090907      Angel Axel Cuaxilo Rodirguez     ISC        100.0
# 200           17091058  Everest Daniel Gutierrez Andrade     ISC        100.0
# 400           18091045    Aurora de Jesus Linares Jacobo     ISC        100.0
# 3             18091054            Mario Martinez Arteaga     ISC          NaN
# 4             18091065               Yeel Montes Camacho     ISC         50.0
# 5             19090356            Georgina Itzel Alvarez     ISC        150.0
# 6             19090333                    Britney Spears     ADM         80.0
# 7             18090233            Adrian Flores Herreram     ISC        100.0
# 8             18091049              Miriam Luna Aparicio     ISC        100.0
# 9             18090961    Salvador Jesus Barbina Cabrera     ISC        100.0
# 10            21091037                     Hernán Cortés    QUIM        100.0
# ...
